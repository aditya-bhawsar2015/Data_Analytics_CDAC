# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = pd.read_csv(r'tips (1).csv')

total_bill_series = data['total_bill']

# Normality test with shapiro - wilk test
shapiro_test = stats.shapiro(total_bill_series)
print("Test statistics (W) : ",shapiro_test.statistic)
print("p-value : ", shapiro_test.pvalue)

alpha = 0.05        # common significance level

if shapiro_test.pvalue > alpha:
    print("Data is normally distributed")
else:
    print("Data is not normally distributed")    

#QQ Plot

stats.probplot(total_bill_series, dist="norm", plot=plt)    
plt.title('QQ Plot of total bill')
plt.xlabel('Theoritical Quantiles (Normal Distribh=ution)')
plt.ylabel('Orderved Values (Total Bill)')
plt.grid(True)
plt.show()
# Out:
# Test statistics (W) :  0.9197188019752502
# p-value :  3.3245434183371003e-10
# Data is not normally distributed

# %%
total_bill_series = data['price_per_person']

# Normality test with shapiro - wilk test
shapiro_test = stats.shapiro(total_bill_series)
print("Test statistics (W) : ",shapiro_test.statistic)
print("p-value : ", shapiro_test.pvalue)

alpha = 0.05        # common significance level

if shapiro_test.pvalue > alpha:
    print("Data is normally distributed")
else:
    print("Data is not normally distributed")    

#QQ Plot

stats.probplot(total_bill_series, dist="norm", plot=plt)    
plt.title('QQ Plot of total bill')
plt.xlabel('Theoritical Quantiles (Normal Distribh=ution)')
plt.ylabel('Orderved Values (Total Bill)')
plt.grid(True)
plt.show()
# Out:
# Test statistics (W) :  0.921815037727356
# p-value :  4.896873462278961e-10
# Data is not normally distributed
